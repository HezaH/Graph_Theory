# %% [markdown]
# # Análise Comparativa de Grafos - Graph6
#
# Este notebook realiza análise completa de grafos em formato Graph6 (.g6), calculando métricas de centralidade e conectividade, além de gerar visualizações e uma análise comparativa em DataFrame.
#
# ## Estrutura do Notebook
# 1. **Imports e configuração**
# 2. **Funções de carregamento**
# 3. **Funções de visualização**
# 4. **Funções de cálculo de métricas**
# 5. **Função principal de análise**
# 6. **Execução e resultados**

# %% [markdown]
# ## 1. Imports e Configuração
#
# Importação das bibliotecas necessárias para análise de grafos, visualização e manipulação de dados.

# %%
import os
import networkx as nx
import matplotlib.pyplot as plt
import statistics
import pandas as pd

# %% [markdown]
# ## 2. Função de Carregamento de Grafos
#
# Função para ler arquivos `.g6` que podem conter um ou mais grafos (um por linha).
# Suporta formatos Graph6 e Sparse6.

# %%
def load_graphs_from_graph6_file(path):
    """
    Reads a .g6 file that can contain one or more graphs (one per line).
    Returns a list of NetworkX graphs.
    """
    graphs = []
    with open(path, "rb") as f:
        for raw in f:
            line = raw.strip()
            if not line:
                continue
            # Ignores optional ">>graph6<<" header if it appears
            if line == b">>graph6<<":
                continue
            # Graph6 typically starts without ":"; Sparse6 starts with ":".
            if line.startswith(b":"):
                # Sparse6 line
                G = nx.from_sparse6_bytes(line)
            else:
                # Graph6 line
                G = nx.from_graph6_bytes(line)
            graphs.append(G)
    return graphs

# %% [markdown]
# ## 3. Funções de Visualização
#
# Duas funções para visualizar grafos:
# - **visualize_graph**: Desenha o grafo com nós e arestas
# - **plot_adjacency_matrix**: Exibe a matriz de adjacência como heatmap

# %%
def visualize_graph(G, title="Graph Visualization", file_name="graph.png"):
    """Visualiza o grafo e salva como imagem."""
    plt.figure(figsize=(6, 6))
    pos = nx.spring_layout(G, seed=42)
    
    nx.draw(
        G, pos,
        with_labels=True,
        node_color="lightblue",
        node_size=800,
        font_size=10,
        font_weight="bold",
        edge_color="gray"
    )
    
    plt.title(title, fontsize=14)
    plt.savefig(file_name)   # save instead of show
    plt.close()              # close the figure so nothing opens

# %%
def plot_adjacency_matrix(G: nx.Graph, title: str = "Adjacency Matrix", file_name="adjacency_matrix.png"):
    """
    Exibe a matriz de adjacência do grafo como um heatmap.
    - Mostra rótulos de nós quando o grafo é pequeno (<= 20 nós).
    - Salva a imagem em arquivo.
    """
    # Define ordem estável de nós (tenta ordenar caso comparáveis)
    nodes = list(G.nodes())
    try:
        nodes = sorted(nodes)
    except Exception:
        pass

    A = nx.to_numpy_array(G, nodelist=nodes, dtype=float)

    plt.figure(figsize=(6, 6))
    im = plt.imshow(A, cmap="Blues", interpolation="nearest")
    plt.title(title, fontsize=14)
    plt.xlabel("Nodes")
    plt.ylabel("Nodes")

    n = len(nodes)
    if n <= 20:
        plt.xticks(range(n), nodes, rotation=90)
        plt.yticks(range(n), nodes)
    else:
        plt.xticks([])
        plt.yticks([])

    plt.colorbar(im, fraction=0.046, pad=0.04)
    plt.tight_layout()
    plt.savefig(file_name)   # save instead of show
    plt.close()              # close the figure so nothing opens

# %% [markdown]
# ## 4. Funções de Cálculo de Métricas
#
# ### 4.1 Cálculo de Centralidades
#
# Calcula diversas medidas de centralidade e conectividade, retornando estatísticas resumidas (média, mínimo, máximo, desvio padrão) para métricas por-nó.

# %%
def calculate_centralities(G: nx.Graph, measures: dict):
    """
    Apply a set of measures (centralities/connectivities) to a graph.
    measures: dict {label: function}
    Returns: dict with summary statistics
    """
    results = {}
    for label, func in measures.items():
        try:
            if label == "Algebraic Connectivity":
                result = func(G, method="lanczos")
            elif label == "Katz Centrality":
                result = func(G, alpha=0.005, beta=1.0, max_iter=2000)
            elif label == "PageRank":
                result = func(G, alpha=0.85)
            else:
                result = func(G)
            print(f"\n>>> {label}:")
            
            # If result is a dict (per-node values)
            if isinstance(result, dict):
                # Calculate summary statistics
                values = list(result.values())
                average_value = sum(values) / len(values)
                min_value = min(values)
                max_value = max(values)
                std_dev = statistics.pstdev(values)
                
                # Store results for DataFrame
                results[label] = {
                    "Average": average_value,
                    "Minimum": min_value,
                    "Maximum": max_value,
                    "Standard Deviation": std_dev
                }
                print(f"Average_{label}: {average_value:.4f}")
                print(f"Minimum_{label}: {min_value:.4f}")
                print(f"Maximum_{label}: {max_value:.4f}")
                print(f"Standard_Deviation_{label}: {std_dev:.4f}")
            else:
                # Single numeric value
                results[label] = {"Value": result}
                print(f"Value: {result}")
                
        except Exception as e:
            print(f"Error computing {label}: {e}")
            results[label] = {"Error": str(e)}
    return results

# %% [markdown]
# ### 4.2 Avaliação de Conectividade Básica
#
# Calcula métricas básicas de conectividade:
# - Número de componentes conectados
# - Tamanho do maior componente
# - Diâmetro do grafo (do maior componente)

# %%
def evaluate_connectivity(G):
    """
    Evaluate basic connectivity measures of a graph.
    
    Returns:
    - dictionary with:
        * number of connected components
        * size of the largest connected component
        * diameter of the graph (largest component)
    """
    # Number of connected components
    num_components = nx.number_connected_components(G)
    
    # Largest connected component
    components = list(nx.connected_components(G))
    largest_component = max(components, key=len)
    largest_size = len(largest_component)
    
    # Subgraph induced by the largest component
    largest_subgraph = G.subgraph(largest_component)
    
    # Diameter of the largest component
    diameter = nx.diameter(largest_subgraph)
    
    result = {
        "Number of connected components": num_components,
        "Size of largest component": largest_size,
        "Graph diameter": diameter
    }
    print("\n>>> Connectivity Measures:")
    for key, value in result.items():
        print(f"{key}: {value}")
    return result

# %% [markdown]
# ## 5. Função Principal de Análise
#
# A função `main` processa todos os arquivos `.g6` de uma pasta e:
# 1. Carrega os grafos
# 2. Gera visualizações (grafo e matriz de adjacência)
# 3. Calcula centralidades
# 4. Avalia conectividade
# 5. **Cria um DataFrame comparativo** com todas as métricas
# 6. Exibe resumo final

# %%
def main(folder: str):
    """Função principal para processar todos os grafos e gerar análise comparativa."""
    # Dictionary to store the loaded graphs
    graphs = {}

    # Dicionários de medidas de centralidade
    dict_centralities = {
        # Standard centrality measures
        "Degree": nx.degree_centrality,
        "Closeness": nx.closeness_centrality,
        "Betweenness": nx.betweenness_centrality,
        "Eigenvector": nx.eigenvector_centrality,
        
        # Additional centrality measures
        "Katz Centrality": nx.katz_centrality,
        "PageRank": nx.pagerank,
        "Harmonic Centrality": nx.harmonic_centrality,
        "Current-flow Betweenness": nx.current_flow_betweenness_centrality
    }
    
    # Dicionários de medidas de conectividade
    dict_connectivity = {
        # Standard connectivity measures
        "Node Connectivity": nx.node_connectivity,
        "Edge Connectivity": nx.edge_connectivity,
        "Algebraic Connectivity": nx.algebraic_connectivity,

        # Additional connectivity measures
        "Average Node Connectivity": nx.average_node_connectivity,
        "Graph Density": nx.density,
        "Average Shortest Path Length": nx.average_shortest_path_length,
        "Global Clustering Coefficient": nx.transitivity,
        "Minimum Node Cut": nx.minimum_node_cut,
        "Minimum Edge Cut": nx.minimum_edge_cut
    }
    
    # DataFrame para armazenar resultados comparativos
    results_df = pd.DataFrame()

    # Iterates through all files in the folder
    for file in sorted(os.listdir(folder)):
        if file.endswith(".g6"):
            file_path = os.path.join(folder, file)
            print(f"\nProcessing file: {file}")
            try:
                graph_list = load_graphs_from_graph6_file(file_path)
                graphs[file] = graph_list
                
                for i, G in enumerate(graph_list):
                    print(f"\n{'='*80}")
                    print(f"GRAPH {i} from {file}")
                    print(f"Nodes: {G.number_of_nodes()}, Edges: {G.number_of_edges()}")
                    print(f"{'='*80}")
                    
                    #! A) Graph visualization
                    visualize_graph(G, title=f"{file} - graph {i}", 
                                  file_name=f"graph_{file}_graph_{i}.png")
                    
                    #! A2) Adjacency matrix
                    plot_adjacency_matrix(G, title=f"Adjacency Matrix - {file} - graph {i}", 
                                        file_name=f"adjacency_{file}_graph_{i}.png")
                    
                    #! B) Centrality calculations
                    results_centralities = calculate_centralities(G, dict_centralities)
                    
                    #! C) Connectivity evaluation
                    dict_evaluate = evaluate_connectivity(G)
                    
                    #! C2) Additional connectivity measures
                    results_connectivity = calculate_centralities(G, dict_connectivity)

                    # Construir linha do DataFrame
                    new_row = {
                        "File": file,
                        "Graph_Index": i,
                        "Num_Nodes": G.number_of_nodes(),
                        "Num_Edges": G.number_of_edges(),
                        **{f"Centrality_{k}_{stat}": v 
                           for k, stats in results_centralities.items() 
                           for stat, v in stats.items()},
                        **{f"Connectivity_{k}_{stat}": v 
                           for k, stats in results_connectivity.items() 
                           for stat, v in stats.items()},
                        **{k: v for k, v in dict_evaluate.items()}
                    }
                    results_df = pd.concat([results_df, pd.DataFrame([new_row])], ignore_index=True)

            except Exception as e:
                print(f"Failed to read {file}: {e}")

            print(f"\n>>> Finished processing {file}.")

    # Display the loaded graphs information
    print(f"\n{'='*80}")
    print("SUMMARY OF ALL GRAPHS")
    print(f"{'='*80}")
    for name, graph_list in graphs.items():
        total_nodes = sum(G.number_of_nodes() for G in graph_list)
        total_edges = sum(G.number_of_edges() for G in graph_list)
        print(f"{name}: {len(graph_list)} graph(s), {total_nodes} nodes, {total_edges} edges")
    
    return results_df

# %% [markdown]
# ## 6. Execução da Análise
#
# Execute a célula abaixo para processar todos os grafos e gerar o DataFrame comparativo.

# %%
# Executar análise
df_results = main(folder=os.path.join("final_work", "data_base"))
# Out:
# Processing file: graph_1098.g6
#
# ================================================================================
# GRAPH 0 from graph_1098.g6
# Nodes: 112, Edges: 560
# ================================================================================
#
# >>> Degree:
# Average_Degree: 0.0901
# Minimum_Degree: 0.0901
# Maximum_Degree: 0.0901
# Standard_Deviation_Degree: 0.0000
#
# >>> Closeness:
# Average_Closeness: 0.3964
# Minimum_Closeness: 0.3964
# Maximum_Closeness: 0.3964
# Standard_Deviation_Closeness: 0.0000
#
# >>> Betweenness:
# Average_Betweenness: 0.0138
# Minimum_Betweenness: 0.0138
# Maximum_Betweenness: 0.0138
# Standard_Deviation_Betweenness: 0.0000
#
# >>> Eigenvector:
# Average_Eigenvector: 0.0945
# Minimum_Eigenvector: 0.0945
# Maximum_Eigenvector: 0.0945
# Standard_Deviation_Eigenvector: 0.0000
#
# >>> Katz Centrality:
# Average_Katz Centrality: 0.0945
# Minimum_Katz Centrality: 0.0945
# Maximum_Katz Centrality: 0.0945
# Standard_Deviation_Katz Centrality: 0.0000
#
# >>> PageRank:
# Average_PageRank: 0.0089
# Minimum_PageRank: 0.0089
# Maximum_PageRank: 0.0089
# Standard_Deviation_PageRank: 0.0000
#
# >>> Harmonic Centrality:
# Average_Harmonic Centrality: 50.2000
# Minimum_Harmonic Centrality: 50.2000
# Maximum_Harmonic Centrality: 50.2000
# Standard_Deviation_Harmonic Centrality: 0.0000
#
# >>> Current-flow Betweenness:
# Average_Current-flow Betweenness: 0.0286
# Minimum_Current-flow Betweenness: 0.0286
# Maximum_Current-flow Betweenness: 0.0286
# Standard_Deviation_Current-flow Betweenness: 0.0000
#
# >>> Connectivity Measures:
# Number of connected components: 1
# Size of largest component: 112
# Graph diameter: 5
#
# >>> Node Connectivity:
# Value: 10
#
# >>> Edge Connectivity:
# Value: 10
#
# >>> Algebraic Connectivity:
# Value: 5.999999999999999
#
# >>> Average Node Connectivity:
# Value: 10.0
#
# >>> Graph Density:
# Value: 0.09009009009009009
#
# >>> Average Shortest Path Length:
# Value: 2.5225225225225225
#
# >>> Global Clustering Coefficient:
# Value: 0
#
# >>> Minimum Node Cut:
# Value: {0, 100, 101, 70, 72, 106, 86, 91, 92, 95}
#
# >>> Minimum Edge Cut:
# Value: {(5, 111), (55, 111), (25, 111), (63, 111), (4, 111), (57, 111), (23, 111), (61, 111), (46, 111), (31, 111)}
#
# >>> Finished processing graph_1098.g6.
#
# Processing file: graph_1210.g6
#
# ================================================================================
# GRAPH 0 from graph_1210.g6
# Nodes: 112, Edges: 168
# ================================================================================
#
# >>> Degree:
# Average_Degree: 0.0270
# Minimum_Degree: 0.0270
# Maximum_Degree: 0.0270
# Standard_Deviation_Degree: 0.0000
#
# >>> Closeness:
# Average_Closeness: 0.2147
# Minimum_Closeness: 0.2143
# Maximum_Closeness: 0.2151
# Standard_Deviation_Closeness: 0.0004
#
# >>> Betweenness:
# Average_Betweenness: 0.0333
# Minimum_Betweenness: 0.0333
# Maximum_Betweenness: 0.0333
# Standard_Deviation_Betweenness: 0.0000
#
# >>> Eigenvector:
# Average_Eigenvector: 0.0945
# Minimum_Eigenvector: 0.0945
# Maximum_Eigenvector: 0.0945
# Standard_Deviation_Eigenvector: 0.0000
#
# >>> Katz Centrality:
# Average_Katz Centrality: 0.0945
# Minimum_Katz Centrality: 0.0945
# Maximum_Katz Centrality: 0.0945
# Standard_Deviation_Katz Centrality: 0.0000
#
# >>> PageRank:
# Average_PageRank: 0.0089
# Minimum_PageRank: 0.0089
# Maximum_PageRank: 0.0089
# Standard_Deviation_PageRank: 0.0000
#
# >>> Harmonic Centrality:
# Average_Harmonic Centrality: 27.9458
# Minimum_Harmonic Centrality: 27.9250
# Maximum_Harmonic Centrality: 27.9667
# Standard_Deviation_Harmonic Centrality: 0.0208
#
# >>> Current-flow Betweenness:
# Average_Current-flow Betweenness: 0.0623
# Minimum_Current-flow Betweenness: 0.0623
# Maximum_Current-flow Betweenness: 0.0623
# Standard_Deviation_Current-flow Betweenness: 0.0000
#
# >>> Connectivity Measures:
# Number of connected components: 1
# Size of largest component: 112
# Graph diameter: 8
#
# >>> Node Connectivity:
# Value: 3
#
# >>> Edge Connectivity:
# Value: 3
#
# >>> Algebraic Connectivity:
# Value: 0.43844718719117043
#
# >>> Average Node Connectivity:
# Value: 3.0
#
# >>> Graph Density:
# Value: 0.02702702702702703
#
# >>> Average Shortest Path Length:
# Value: 4.657657657657658
#
# >>> Global Clustering Coefficient:
# Value: 0
#
# >>> Minimum Node Cut:
# Value: {0, 107, 111}
#
# >>> Minimum Edge Cut:
# Value: {(104, 111), (3, 111), (101, 111)}
#
# >>> Finished processing graph_1210.g6.
#
# Processing file: graph_1312.g6
#
# ================================================================================
# GRAPH 0 from graph_1312.g6
# Nodes: 120, Edges: 720
# ================================================================================
#
# >>> Degree:
# Average_Degree: 0.1008
# Minimum_Degree: 0.1008
# Maximum_Degree: 0.1008
# Standard_Deviation_Degree: 0.0000
#
# >>> Closeness:
# Average_Closeness: 0.3552
# Minimum_Closeness: 0.3552
# Maximum_Closeness: 0.3552
# Standard_Deviation_Closeness: 0.0000
#
# >>> Betweenness:
# Average_Betweenness: 0.0154
# Minimum_Betweenness: 0.0154
# Maximum_Betweenness: 0.0154
# Standard_Deviation_Betweenness: 0.0000
#
# >>> Eigenvector:
# Average_Eigenvector: 0.0913
# Minimum_Eigenvector: 0.0913
# Maximum_Eigenvector: 0.0913
# Standard_Deviation_Eigenvector: 0.0000
#
# >>> Katz Centrality:
# Average_Katz Centrality: 0.0913
# Minimum_Katz Centrality: 0.0913
# Maximum_Katz Centrality: 0.0913
# Standard_Deviation_Katz Centrality: 0.0000
#
# >>> PageRank:
# Average_PageRank: 0.0083
# Minimum_PageRank: 0.0083
# Maximum_PageRank: 0.0083
# Standard_Deviation_PageRank: 0.0000
#
# >>> Harmonic Centrality:
# Average_Harmonic Centrality: 50.2000
# Minimum_Harmonic Centrality: 50.2000
# Maximum_Harmonic Centrality: 50.2000
# Standard_Deviation_Harmonic Centrality: 0.0000
#
# >>> Current-flow Betweenness:
# Average_Current-flow Betweenness: 0.0372
# Minimum_Current-flow Betweenness: 0.0372
# Maximum_Current-flow Betweenness: 0.0372
# Standard_Deviation_Current-flow Betweenness: 0.0000
#
# >>> Connectivity Measures:
# Number of connected components: 1
# Size of largest component: 120
# Graph diameter: 5
#
# >>> Node Connectivity:
# Value: 12
#
# >>> Edge Connectivity:
# Value: 12
#
# >>> Algebraic Connectivity:
# Value: 2.291796067500632
#
# >>> Average Node Connectivity:
# Value: 12.0
#
# >>> Graph Density:
# Value: 0.10084033613445378
#
# >>> Average Shortest Path Length:
# Value: 2.8151260504201683
#
# >>> Global Clustering Coefficient:
# Value: 0.45454545454545453
#
# >>> Minimum Node Cut:
# Value: {0, 3, 6, 7, 8, 107, 12, 110, 108, 114, 118, 93}
#
# >>> Minimum Edge Cut:
# Value: {(103, 99), (75, 99), (114, 99), (87, 99), (104, 99), (57, 99), (58, 99), (118, 99), (86, 99), (119, 99), (76, 99), (6, 99)}
#
# >>> Finished processing graph_1312.g6.
#
# Processing file: graph_660_petersen_graph.g6
#
# ================================================================================
# GRAPH 0 from graph_660_petersen_graph.g6
# Nodes: 10, Edges: 15
# ================================================================================
#
# >>> Degree:
# Average_Degree: 0.3333
# Minimum_Degree: 0.3333
# Maximum_Degree: 0.3333
# Standard_Deviation_Degree: 0.0000
#
# >>> Closeness:
# Average_Closeness: 0.6000
# Minimum_Closeness: 0.6000
# Maximum_Closeness: 0.6000
# Standard_Deviation_Closeness: 0.0000
#
# >>> Betweenness:
# Average_Betweenness: 0.0833
# Minimum_Betweenness: 0.0833
# Maximum_Betweenness: 0.0833
# Standard_Deviation_Betweenness: 0.0000
#
# >>> Eigenvector:
# Average_Eigenvector: 0.3162
# Minimum_Eigenvector: 0.3162
# Maximum_Eigenvector: 0.3162
# Standard_Deviation_Eigenvector: 0.0000
#
# >>> Katz Centrality:
# Average_Katz Centrality: 0.3162
# Minimum_Katz Centrality: 0.3162
# Maximum_Katz Centrality: 0.3162
# Standard_Deviation_Katz Centrality: 0.0000
#
# >>> PageRank:
# Average_PageRank: 0.1000
# Minimum_PageRank: 0.1000
# Maximum_PageRank: 0.1000
# Standard_Deviation_PageRank: 0.0000
#
# >>> Harmonic Centrality:
# Average_Harmonic Centrality: 6.0000
# Minimum_Harmonic Centrality: 6.0000
# Maximum_Harmonic Centrality: 6.0000
# Standard_Deviation_Harmonic Centrality: 0.0000
#
# >>> Current-flow Betweenness:
# Average_Current-flow Betweenness: 0.2000
# Minimum_Current-flow Betweenness: 0.2000
# Maximum_Current-flow Betweenness: 0.2000
# Standard_Deviation_Current-flow Betweenness: 0.0000
#
# >>> Connectivity Measures:
# Number of connected components: 1
# Size of largest component: 10
# Graph diameter: 2
#
# >>> Node Connectivity:
# Value: 3
#
# >>> Edge Connectivity:
# Value: 3
#
# >>> Algebraic Connectivity:
# Value: 1.9999999999999998
#
# >>> Average Node Connectivity:
# Value: 3.0
#
# >>> Graph Density:
# Value: 0.3333333333333333
#
# >>> Average Shortest Path Length:
# Value: 1.6666666666666667
#
# >>> Global Clustering Coefficient:
# Value: 0
#
# >>> Minimum Node Cut:
# Value: {0, 8, 7}
#
# >>> Minimum Edge Cut:
# Value: {(9, 5), (7, 5), (1, 5)}
#
# >>> Finished processing graph_660_petersen_graph.g6.
#
# ================================================================================
# SUMMARY OF ALL GRAPHS
# ================================================================================
# graph_1098.g6: 1 graph(s), 112 nodes, 560 edges
# graph_1210.g6: 1 graph(s), 112 nodes, 168 edges
# graph_1312.g6: 1 graph(s), 120 nodes, 720 edges
# graph_660_petersen_graph.g6: 1 graph(s), 10 nodes, 15 edges

# %% [markdown]
# ## 7. Visualização do DataFrame Comparativo
#
# Visualize as primeiras linhas do DataFrame com todas as métricas calculadas.

# %%
# Exibir informações do DataFrame
print(f"Total de grafos analisados: {len(df_results)}")
print(f"Total de colunas (métricas): {len(df_results.columns)}")
print("\nPrimeiras linhas do DataFrame:")
df_results.head()
# Out:
# Total de grafos analisados: 4
# Total de colunas (métricas): 48
#
# Primeiras linhas do DataFrame:
#                           File  Graph_Index  Num_Nodes  Num_Edges  \
# 0                graph_1098.g6            0        112        560
# 1                graph_1210.g6            0        112        168
# 2                graph_1312.g6            0        120        720
# 3  graph_660_petersen_graph.g6            0         10         15
#
#    Centrality_Degree_Average  Centrality_Degree_Minimum  \
# 0                   0.090090                   0.090090
# 1                   0.027027                   0.027027
# 2                   0.100840                   0.100840
# 3                   0.333333                   0.333333
#
#    Centrality_Degree_Maximum  Centrality_Degree_Standard Deviation  \
# 0                   0.090090                                   0.0
# 1                   0.027027                                   0.0
# 2                   0.100840                                   0.0
# 3                   0.333333                                   0.0
#
#    Centrality_Closeness_Average  Centrality_Closeness_Minimum  ...  \
# 0                      0.396429                      0.396429  ...
# 1                      0.214701                      0.214286  ...
# 2                      0.355224                      0.355224  ...
# 3                      0.600000                      0.600000  ...
#
#    Connectivity_Algebraic Connectivity_Value  \
# 0                                   6.000000
# 1                                   0.438447
# 2                                   2.291796
# 3                                   2.000000
#
#    Connectivity_Average Node Connectivity_Value  \
# 0                                          10.0
# 1                                           3.0
# 2                                          12.0
# 3                                           3.0
#
#    Connectivity_Graph Density_Value  \
# 0                          0.090090
# 1                          0.027027
# 2                          0.100840
# 3                          0.333333
#
#    Connectivity_Average Shortest Path Length_Value  \
# 0                                         2.522523
# 1                                         4.657658
# 2                                         2.815126
# 3                                         1.666667
#
#    Connectivity_Global Clustering Coefficient_Value  \
# 0                                          0.000000
# 1                                          0.000000
# 2                                          0.454545
# 3                                          0.000000
#
#                 Connectivity_Minimum Node Cut_Value  \
# 0        {0, 100, 101, 70, 72, 106, 86, 91, 92, 95}
# 1                                     {0, 107, 111}
# 2  {0, 3, 6, 7, 8, 107, 12, 110, 108, 114, 118, 93}
# 3                                         {0, 8, 7}
#
#                  Connectivity_Minimum Edge Cut_Value  \
# 0  {(5, 111), (55, 111), (25, 111), (63, 111), (4...
# 1                 {(104, 111), (3, 111), (101, 111)}
# 2  {(103, 99), (75, 99), (114, 99), (87, 99), (10...
# 3                           {(9, 5), (7, 5), (1, 5)}
#
#    Number of connected components  Size of largest component  Graph diameter
# 0                               1                        112               5
# 1                               1                        112               8
# 2                               1                        120               5
# 3                               1                         10               2
#
# [4 rows x 48 columns]

# %% [markdown]
# ## 8. Análise Exploratória das Métricas
#
# ### 8.1 Estatísticas Descritivas

# %%
# Estatísticas descritivas de métricas numéricas
df_results.describe().T
# Out:
#                                                     count          mean  \
# Graph_Index                                           4.0  0.000000e+00
# Num_Nodes                                             4.0  8.850000e+01
# Num_Edges                                             4.0  3.657500e+02
# Centrality_Degree_Average                             4.0  1.378227e-01
# Centrality_Degree_Minimum                             4.0  1.378227e-01
# Centrality_Degree_Maximum                             4.0  1.378227e-01
# Centrality_Degree_Standard Deviation                  4.0  0.000000e+00
# Centrality_Closeness_Average                          4.0  3.915884e-01
# Centrality_Closeness_Minimum                          4.0  3.914845e-01
# Centrality_Closeness_Maximum                          4.0  3.916922e-01
# Centrality_Closeness_Standard Deviation               4.0  1.038206e-04
# Centrality_Betweenness_Average                        4.0  3.645208e-02
# Centrality_Betweenness_Minimum                        4.0  3.645208e-02
# Centrality_Betweenness_Maximum                        4.0  3.645208e-02
# Centrality_Betweenness_Standard Deviation             4.0  4.798484e-18
# Centrality_Eigenvector_Average                        4.0  1.491243e-01
# Centrality_Eigenvector_Minimum                        4.0  1.491243e-01
# Centrality_Eigenvector_Maximum                        4.0  1.491243e-01
# Centrality_Eigenvector_Standard Deviation             4.0  0.000000e+00
# Centrality_Katz Centrality_Average                    4.0  1.491243e-01
# Centrality_Katz Centrality_Minimum                    4.0  1.491243e-01
# Centrality_Katz Centrality_Maximum                    4.0  1.491243e-01
# Centrality_Katz Centrality_Standard Deviation         4.0  0.000000e+00
# Centrality_PageRank_Average                           4.0  3.154762e-02
# Centrality_PageRank_Minimum                           4.0  3.154762e-02
# Centrality_PageRank_Maximum                           4.0  3.154762e-02
# Centrality_PageRank_Standard Deviation                4.0  0.000000e+00
# Centrality_Harmonic Centrality_Average                4.0  3.358646e+01
# Centrality_Harmonic Centrality_Minimum                4.0  3.358125e+01
# Centrality_Harmonic Centrality_Maximum                4.0  3.359167e+01
# Centrality_Harmonic Centrality_Standard Deviation     4.0  5.208333e-03
# Centrality_Current-flow Betweenness_Average           4.0  8.202546e-02
# Centrality_Current-flow Betweenness_Minimum           4.0  8.202546e-02
# Centrality_Current-flow Betweenness_Maximum           4.0  8.202546e-02
# Centrality_Current-flow Betweenness_Standard De...    4.0  5.044919e-17
# Connectivity_Node Connectivity_Value                  4.0  7.000000e+00
# Connectivity_Edge Connectivity_Value                  4.0  7.000000e+00
# Connectivity_Algebraic Connectivity_Value             4.0  2.682561e+00
# Connectivity_Average Node Connectivity_Value          4.0  7.000000e+00
# Connectivity_Graph Density_Value                      4.0  1.378227e-01
# Connectivity_Average Shortest Path Length_Value       4.0  2.915493e+00
# Connectivity_Global Clustering Coefficient_Value      4.0  1.136364e-01
# Number of connected components                        4.0  1.000000e+00
# Size of largest component                             4.0  8.850000e+01
# Graph diameter                                        4.0  5.000000e+00
#
#                                                              std  \
# Graph_Index                                         0.000000e+00
# Num_Nodes                                           5.246904e+01
# Num_Edges                                           3.293209e+02
# Centrality_Degree_Average                           1.343456e-01
# Centrality_Degree_Minimum                           1.343456e-01
# Centrality_Degree_Maximum                           1.343456e-01
# Centrality_Degree_Standard Deviation                0.000000e+00
# Centrality_Closeness_Average                        1.592381e-01
# Centrality_Closeness_Minimum                        1.593920e-01
# Centrality_Closeness_Maximum                        1.590844e-01
# Centrality_Closeness_Standard Deviation             2.076412e-04
# Centrality_Betweenness_Average                      3.247195e-02
# Centrality_Betweenness_Minimum                      3.247195e-02
# Centrality_Betweenness_Maximum                      3.247195e-02
# Centrality_Betweenness_Standard Deviation           3.285098e-18
# Centrality_Eigenvector_Average                      1.114126e-01
# Centrality_Eigenvector_Minimum                      1.114126e-01
# Centrality_Eigenvector_Maximum                      1.114126e-01
# Centrality_Eigenvector_Standard Deviation           0.000000e+00
# Centrality_Katz Centrality_Average                  1.114126e-01
# Centrality_Katz Centrality_Minimum                  1.114126e-01
# Centrality_Katz Centrality_Maximum                  1.114126e-01
# Centrality_Katz Centrality_Standard Deviation       0.000000e+00
# Centrality_PageRank_Average                         4.563578e-02
# Centrality_PageRank_Minimum                         4.563578e-02
# Centrality_PageRank_Maximum                         4.563578e-02
# Centrality_PageRank_Standard Deviation              0.000000e+00
# Centrality_Harmonic Centrality_Average              2.117269e+01
# Centrality_Harmonic Centrality_Minimum              2.117455e+01
# Centrality_Harmonic Centrality_Maximum              2.117085e+01
# Centrality_Harmonic Centrality_Standard Deviation   1.041667e-02
# Centrality_Current-flow Betweenness_Average         7.993780e-02
# Centrality_Current-flow Betweenness_Minimum         7.993780e-02
# Centrality_Current-flow Betweenness_Maximum         7.993780e-02
# Centrality_Current-flow Betweenness_Standard De...  7.201537e-18
# Connectivity_Node Connectivity_Value                4.690416e+00
# Connectivity_Edge Connectivity_Value                4.690416e+00
# Connectivity_Algebraic Connectivity_Value           2.356554e+00
# Connectivity_Average Node Connectivity_Value        4.690416e+00
# Connectivity_Graph Density_Value                    1.343456e-01
# Connectivity_Average Shortest Path Length_Value     1.259524e+00
# Connectivity_Global Clustering Coefficient_Value    2.272727e-01
# Number of connected components                      0.000000e+00
# Size of largest component                           5.246904e+01
# Graph diameter                                      2.449490e+00
#
#                                                              min  \
# Graph_Index                                         0.000000e+00
# Num_Nodes                                           1.000000e+01
# Num_Edges                                           1.500000e+01
# Centrality_Degree_Average                           2.702703e-02
# Centrality_Degree_Minimum                           2.702703e-02
# Centrality_Degree_Maximum                           2.702703e-02
# Centrality_Degree_Standard Deviation                0.000000e+00
# Centrality_Closeness_Average                        2.147010e-01
# Centrality_Closeness_Minimum                        2.142857e-01
# Centrality_Closeness_Maximum                        2.151163e-01
# Centrality_Closeness_Standard Deviation             0.000000e+00
# Centrality_Betweenness_Average                      1.384111e-02
# Centrality_Betweenness_Minimum                      1.384111e-02
# Centrality_Betweenness_Maximum                      1.384111e-02
# Centrality_Betweenness_Standard Deviation           0.000000e+00
# Centrality_Eigenvector_Average                      9.128709e-02
# Centrality_Eigenvector_Minimum                      9.128709e-02
# Centrality_Eigenvector_Maximum                      9.128709e-02
# Centrality_Eigenvector_Standard Deviation           0.000000e+00
# Centrality_Katz Centrality_Average                  9.128709e-02
# Centrality_Katz Centrality_Minimum                  9.128709e-02
# Centrality_Katz Centrality_Maximum                  9.128709e-02
# Centrality_Katz Centrality_Standard Deviation       0.000000e+00
# Centrality_PageRank_Average                         8.333333e-03
# Centrality_PageRank_Minimum                         8.333333e-03
# Centrality_PageRank_Maximum                         8.333333e-03
# Centrality_PageRank_Standard Deviation              0.000000e+00
# Centrality_Harmonic Centrality_Average              6.000000e+00
# Centrality_Harmonic Centrality_Minimum              6.000000e+00
# Centrality_Harmonic Centrality_Maximum              6.000000e+00
# Centrality_Harmonic Centrality_Standard Deviation   0.000000e+00
# Centrality_Current-flow Betweenness_Average         2.861238e-02
# Centrality_Current-flow Betweenness_Minimum         2.861238e-02
# Centrality_Current-flow Betweenness_Maximum         2.861238e-02
# Centrality_Current-flow Betweenness_Standard De...  4.030824e-17
# Connectivity_Node Connectivity_Value                3.000000e+00
# Connectivity_Edge Connectivity_Value                3.000000e+00
# Connectivity_Algebraic Connectivity_Value           4.384472e-01
# Connectivity_Average Node Connectivity_Value        3.000000e+00
# Connectivity_Graph Density_Value                    2.702703e-02
# Connectivity_Average Shortest Path Length_Value     1.666667e+00
# Connectivity_Global Clustering Coefficient_Value    0.000000e+00
# Number of connected components                      1.000000e+00
# Size of largest component                           1.000000e+01
# Graph diameter                                      2.000000e+00
#
#                                                              25%  \
# Graph_Index                                         0.000000e+00
# Num_Nodes                                           8.650000e+01
# Num_Edges                                           1.297500e+02
# Centrality_Degree_Average                           7.432432e-02
# Centrality_Degree_Minimum                           7.432432e-02
# Centrality_Degree_Maximum                           7.432432e-02
# Centrality_Degree_Standard Deviation                0.000000e+00
# Centrality_Closeness_Average                        3.200932e-01
# Centrality_Closeness_Minimum                        3.199893e-01
# Centrality_Closeness_Maximum                        3.201970e-01
# Centrality_Closeness_Standard Deviation             0.000000e+00
# Centrality_Betweenness_Average                      1.499710e-02
# Centrality_Betweenness_Minimum                      1.499710e-02
# Centrality_Betweenness_Maximum                      1.499710e-02
# Centrality_Betweenness_Standard Deviation           4.018957e-18
# Centrality_Eigenvector_Average                      9.369011e-02
# Centrality_Eigenvector_Minimum                      9.369011e-02
# Centrality_Eigenvector_Maximum                      9.369011e-02
# Centrality_Eigenvector_Standard Deviation           0.000000e+00
# Centrality_Katz Centrality_Average                  9.369011e-02
# Centrality_Katz Centrality_Minimum                  9.369011e-02
# Centrality_Katz Centrality_Maximum                  9.369011e-02
# Centrality_Katz Centrality_Standard Deviation       0.000000e+00
# Centrality_PageRank_Average                         8.779762e-03
# Centrality_PageRank_Minimum                         8.779762e-03
# Centrality_PageRank_Maximum                         8.779762e-03
# Centrality_PageRank_Standard Deviation              0.000000e+00
# Centrality_Harmonic Centrality_Average              2.245938e+01
# Centrality_Harmonic Centrality_Minimum              2.244375e+01
# Centrality_Harmonic Centrality_Maximum              2.247500e+01
# Centrality_Harmonic Centrality_Standard Deviation   1.071866e-14
# Centrality_Current-flow Betweenness_Average         3.504747e-02
# Centrality_Current-flow Betweenness_Minimum         3.504747e-02
# Centrality_Current-flow Betweenness_Maximum         3.504747e-02
# Centrality_Current-flow Betweenness_Standard De...  4.798934e-17
# Connectivity_Node Connectivity_Value                3.000000e+00
# Connectivity_Edge Connectivity_Value                3.000000e+00
# Connectivity_Algebraic Connectivity_Value           1.609612e+00
# Connectivity_Average Node Connectivity_Value        3.000000e+00
# Connectivity_Graph Density_Value                    7.432432e-02
# Connectivity_Average Shortest Path Length_Value     2.308559e+00
# Connectivity_Global Clustering Coefficient_Value    0.000000e+00
# Number of connected components                      1.000000e+00
# Size of largest component                           8.650000e+01
# Graph diameter                                      4.250000e+00
#
#                                                              50%  \
# Graph_Index                                         0.000000e+00
# Num_Nodes                                           1.120000e+02
# Num_Edges                                           3.640000e+02
# Centrality_Degree_Average                           9.546521e-02
# Centrality_Degree_Minimum                           9.546521e-02
# Centrality_Degree_Maximum                           9.546521e-02
# Centrality_Degree_Standard Deviation                0.000000e+00
# Centrality_Closeness_Average                        3.758262e-01
# Centrality_Closeness_Minimum                        3.758262e-01
# Centrality_Closeness_Maximum                        3.758262e-01
# Centrality_Closeness_Standard Deviation             0.000000e+00
# Centrality_Betweenness_Average                      2.431693e-02
# Centrality_Betweenness_Minimum                      2.431693e-02
# Centrality_Betweenness_Maximum                      2.431693e-02
# Centrality_Betweenness_Standard Deviation           6.055536e-18
# Centrality_Eigenvector_Average                      9.449112e-02
# Centrality_Eigenvector_Minimum                      9.449112e-02
# Centrality_Eigenvector_Maximum                      9.449112e-02
# Centrality_Eigenvector_Standard Deviation           0.000000e+00
# Centrality_Katz Centrality_Average                  9.449112e-02
# Centrality_Katz Centrality_Minimum                  9.449112e-02
# Centrality_Katz Centrality_Maximum                  9.449112e-02
# Centrality_Katz Centrality_Standard Deviation       0.000000e+00
# Centrality_PageRank_Average                         8.928571e-03
# Centrality_PageRank_Minimum                         8.928571e-03
# Centrality_PageRank_Maximum                         8.928571e-03
# Centrality_PageRank_Standard Deviation              0.000000e+00
# Centrality_Harmonic Centrality_Average              3.907292e+01
# Centrality_Harmonic Centrality_Minimum              3.906250e+01
# Centrality_Harmonic Centrality_Maximum              3.908333e+01
# Centrality_Harmonic Centrality_Standard Deviation   3.172689e-14
# Centrality_Current-flow Betweenness_Average         4.974473e-02
# Centrality_Current-flow Betweenness_Minimum         4.974473e-02
# Centrality_Current-flow Betweenness_Maximum         4.974473e-02
# Centrality_Current-flow Betweenness_Standard De...  5.246965e-17
# Connectivity_Node Connectivity_Value                6.500000e+00
# Connectivity_Edge Connectivity_Value                6.500000e+00
# Connectivity_Algebraic Connectivity_Value           2.145898e+00
# Connectivity_Average Node Connectivity_Value        6.500000e+00
# Connectivity_Graph Density_Value                    9.546521e-02
# Connectivity_Average Shortest Path Length_Value     2.668824e+00
# Connectivity_Global Clustering Coefficient_Value    0.000000e+00
# Number of connected components                      1.000000e+00
# Size of largest component                           1.120000e+02
# Graph diameter                                      5.000000e+00
#
#                                                              75%           max
# Graph_Index                                         0.000000e+00  0.000000e+00
# Num_Nodes                                           1.140000e+02  1.200000e+02
# Num_Edges                                           6.000000e+02  7.200000e+02
# Centrality_Degree_Average                           1.589636e-01  3.333333e-01
# Centrality_Degree_Minimum                           1.589636e-01  3.333333e-01
# Centrality_Degree_Maximum                           1.589636e-01  3.333333e-01
# Centrality_Degree_Standard Deviation                0.000000e+00  0.000000e+00
# Centrality_Closeness_Average                        4.473214e-01  6.000000e-01
# Centrality_Closeness_Minimum                        4.473214e-01  6.000000e-01
# Centrality_Closeness_Maximum                        4.473214e-01  6.000000e-01
# Centrality_Closeness_Standard Deviation             1.038206e-04  4.152824e-04
# Centrality_Betweenness_Average                      4.577191e-02  8.333333e-02
# Centrality_Betweenness_Minimum                      4.577191e-02  8.333333e-02
# Centrality_Betweenness_Maximum                      4.577191e-02  8.333333e-02
# Centrality_Betweenness_Standard Deviation           6.835063e-18  7.082864e-18
# Centrality_Eigenvector_Average                      1.499253e-01  3.162278e-01
# Centrality_Eigenvector_Minimum                      1.499253e-01  3.162278e-01
# Centrality_Eigenvector_Maximum                      1.499253e-01  3.162278e-01
# Centrality_Eigenvector_Standard Deviation           0.000000e+00  0.000000e+00
# Centrality_Katz Centrality_Average                  1.499253e-01  3.162278e-01
# Centrality_Katz Centrality_Minimum                  1.499253e-01  3.162278e-01
# Centrality_Katz Centrality_Maximum                  1.499253e-01  3.162278e-01
# Centrality_Katz Centrality_Standard Deviation       0.000000e+00  0.000000e+00
# Centrality_PageRank_Average                         3.169643e-02  1.000000e-01
# Centrality_PageRank_Minimum                         3.169643e-02  1.000000e-01
# Centrality_PageRank_Maximum                         3.169643e-02  1.000000e-01
# Centrality_PageRank_Standard Deviation              0.000000e+00  0.000000e+00
# Centrality_Harmonic Centrality_Average              5.020000e+01  5.020000e+01
# Centrality_Harmonic Centrality_Minimum              5.020000e+01  5.020000e+01
# Centrality_Harmonic Centrality_Maximum              5.020000e+01  5.020000e+01
# Centrality_Harmonic Centrality_Standard Deviation   5.208333e-03  2.083333e-02
# Centrality_Current-flow Betweenness_Average         9.672271e-02  2.000000e-01
# Centrality_Current-flow Betweenness_Minimum         9.672271e-02  2.000000e-01
# Centrality_Current-flow Betweenness_Maximum         9.672271e-02  2.000000e-01
# Centrality_Current-flow Betweenness_Standard De...  5.492951e-17  5.654924e-17
# Connectivity_Node Connectivity_Value                1.050000e+01  1.200000e+01
# Connectivity_Edge Connectivity_Value                1.050000e+01  1.200000e+01
# Connectivity_Algebraic Connectivity_Value           3.218847e+00  6.000000e+00
# Connectivity_Average Node Connectivity_Value        1.050000e+01  1.200000e+01
# Connectivity_Graph Density_Value                    1.589636e-01  3.333333e-01
# Connectivity_Average Shortest Path Length_Value     3.275759e+00  4.657658e+00
# Connectivity_Global Clustering Coefficient_Value    1.136364e-01  4.545455e-01
# Number of connected components                      1.000000e+00  1.000000e+00
# Size of largest component                           1.140000e+02  1.200000e+02
# Graph diameter                                      5.750000e+00  8.000000e+00

# %% [markdown]
# ### 8.2 Comparação de Densidade entre Grafos

# %%
# Comparar densidade dos grafos
if 'Connectivity_Graph Density_Value' in df_results.columns:
    density_comparison = df_results[['File', 'Graph_Index', 'Num_Nodes', 'Num_Edges', 
                                      'Connectivity_Graph Density_Value']].sort_values(
        'Connectivity_Graph Density_Value', ascending=False)
    print("Ranking de Densidade dos Grafos:")
    density_comparison
else:
    print("Coluna de densidade não encontrada.")
# Out:
# Ranking de Densidade dos Grafos:

# %% [markdown]
# ### 8.3 Exportar Resultados para CSV

# %%
# Salvar DataFrame em arquivo CSV
output_path = os.path.join("final_work", "results", "comparative_metrics.csv")
os.makedirs(os.path.dirname(output_path), exist_ok=True)
df_results.to_csv(output_path, index=False)
print(f"Resultados salvos em: {output_path}")
# Out:
# Resultados salvos em: final_work\results\comparative_metrics.csv
